# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier as DE
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
comp=pd.read_csv(r"D:\Data Science Assignment\Decission Tree\Company_Data.csv")

# %%
comp
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
comp.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# max    191.000000   80.000000   18.000000

# %%
comp.shape
# Out:
# (400, 11)

# %%
comp.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
sns.boxplot(comp["Sales"])
# Out:
# D:\anaconda\nik\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sales'>

# %%
def split(num):
    if num < 5:
        return "low sale"
    elif num>= 5 and num<10:
        return "average sale"
    else:
        return "high sale"
    
comp.Sales=comp.Sales.apply(split)

# %%
corr=comp.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
comp
# Out:
#             Sales  CompPrice  Income  Advertising  Population  Price  \
# 0    average sale        138      73           11         276    120
# 1       high sale        111      48           16         260     83
# 2       high sale        113      35           10         269     80
# 3    average sale        117     100            4         466     97
# 4        low sale        141      64            3         340    128
# ..            ...        ...     ...          ...         ...    ...
# 395     high sale        138     108           17         203    128
# 396  average sale        139      23            3          37    120
# 397  average sale        162      26           12         368    159
# 398  average sale        100      79            7         284     95
# 399  average sale        134      37            0          27    120
#
#     ShelveLoc  Age  Education Urban   US
# 0         Bad   42         17   Yes  Yes
# 1        Good   65         10   Yes  Yes
# 2      Medium   59         12   Yes  Yes
# 3      Medium   55         14   Yes  Yes
# 4         Bad   38         13   Yes   No
# ..        ...  ...        ...   ...  ...
# 395      Good   33         14   Yes  Yes
# 396    Medium   55         11    No  Yes
# 397    Medium   40         18   Yes  Yes
# 398       Bad   50         12   Yes  Yes
# 399      Good   49         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
le=LabelEncoder()

# %%
comp["ShelveLoc"]=le.fit_transform(comp["ShelveLoc"])
comp["Urban"]=le.fit_transform(comp["Urban"])
comp["US"]=le.fit_transform(comp["US"])

# %%
y=comp.iloc[:,0]
x=comp.iloc[:,1:11]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=DE(criterion="entropy",max_depth=5)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
from sklearn import tree

# %%
tree.plot_tree(model);

# %%
fn=["Sales","CompPrice","Income","Advertising","Population","Price","ShelveLoc","Age","Education","Urban","US"]
cn=["low sale","average sale","high sale"]
fig,axes=plt.subplots(nrows=1,ncols=1,figsize=(1.5,1.5),dpi=5000)
tree.plot_tree(model,feature_names=fn,class_names=cn,filled=True);

# %%
preds=model.predict(x_test)

# %%
preds
# Out:
# array(['average sale', 'average sale', 'average sale', 'average sale',
#        'low sale', 'average sale', 'high sale', 'low sale', 'high sale',
#        'low sale', 'average sale', 'high sale', 'low sale', 'low sale',
#        'average sale', 'average sale', 'average sale', 'low sale',
#        'low sale', 'average sale', 'average sale', 'average sale',
#        'average sale', 'average sale', 'average sale', 'low sale',
#        'average sale', 'low sale', 'average sale', 'high sale',
#        'high sale', 'average sale', 'average sale', 'average sale',
#        'high sale', 'average sale', 'average sale', 'low sale',
#        'average sale', 'low sale', 'average sale', 'average sale',
#        'high sale', 'low sale', 'average sale', 'high sale',
#        'average sale', 'high sale', 'average sale', 'average sale',
#        'low sale', 'high sale', 'average sale', 'high sale',
#        'average sale', 'high sale', 'high sale', 'average sale',
#        'average sale', 'low sale', 'low sale', 'average sale',
#        'average sale', 'high sale', 'average sale', 'average sale',
#        'average sale', 'low sale', 'average sale', 'average sale',
#        'average sale', 'average sale', 'average sale', 'high sale',
#        'average sale', 'high sale', 'average sale', 'average sale',
#        'high sale', 'average sale'], dtype=object)

# %%
confusion_matrix(y_test,preds)
# Out:
# array([[35, 10,  6],
#        [ 6,  7,  1],
#        [ 6,  0,  9]], dtype=int64)

# %%
accuracy_score(y_test,preds)
# Out:
# 0.6375

# %%
pd.Series(preds).value_counts()
# Out:
# average sale    47
# high sale       17
# low sale        16
# dtype: int64

# %%
df=pd.DataFrame({"actual":y_test,"predicted":preds})

# %%
df
# Out:
#            actual     predicted
# 160      low sale  average sale
# 192  average sale  average sale
# 346  average sale  average sale
# 211  average sale  average sale
# 15   average sale      low sale
# ..            ...           ...
# 26   average sale     high sale
# 225  average sale  average sale
# 144  average sale  average sale
# 270     high sale     high sale
# 205  average sale  average sale
#
# [80 rows x 2 columns]
